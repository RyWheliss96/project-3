# %% [markdown]
# Before running any of the following code, make sure you import the dataset with `mongoimport --type json -d harrypotter -c characters --drop --jsonArray HPCharactersDataRaw.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'harrypotter', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the met database to a variable name
db = mongo['harrypotter']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['characters']

# %%
# review a document in the artifacts collection
pprint(db.characters.find_one())
# Out:
# {'Blood': 'Unknown',
#  'Descr': 'Euan Abercrombie was a small boy with prominent ears; it’s implied '
#           'that at the beginning of his first year that he believed the\xa0'
#           'Daily Prophet‘s smear campaign against\xa0Harry\xa0(OP11). ',
#  'Gender': 'Male',
#  'Link': 'https://www.hp-lexicon.org/character/abercrombie-euan/',
#  'Name': 'Euan Abercrombie',
#  'Profession': 'Unknown',
#  'School': 'Hogwarts - Gryffindor',
#  'Species/Race': 'Wizard',
#  '_id': ObjectId('650a41e70846b16813a6827e')}

# %%
# assign the collection to a variable
characters = db['characters']

# %% [markdown]
# ## Explore the Collection

# %%
# Find how many total characters in gryffindor
gryffindor_count = characters.count_documents({'School':'Hogwarts - Gryffindor'})
gryffindor_count
# Out:
# 71

# %%
# Find how many total characters in slytherin
slytherin_count = characters.count_documents({'School':'Hogwarts - Slytherin'})
slytherin_count
# Out:
# 75

# %%
# Find how many total characters in hufflepuff
hufflepuff_count = characters.count_documents({'School':'Hogwarts - Hufflepuff'})
hufflepuff_count
# Out:
# 27

# %%
# Find how many total characters in ravenclaw
ravenclaw_count = characters.count_documents({'School':'Hogwarts - Ravenclaw'})
ravenclaw_count
# Out:
# 42

# %%
unique_characters = characters.distinct('Name')

unique_characters
# Out:
# ['Abel Treetops',
#  'Aberforth Dumbledore',
#  'Abernathy',
#  'Able Fleming',
#  'Able Spudmore',
#  'Abraham Peasegood',
#  'Abraham Potter',
#  'Abraxas Malfoy',
#  'Achilles Tolliver',
#  'Adalbert Waffling',
#  'Adrian Pucey',
#  'Adrian Tutley',
#  'Agatha Chubb',
#  'Agatha Timms',
#  'Agilbert Fontaine',
#  'Agnes',
#  'Aidan Kiely',
#  'Aidan Lynch',
#  'Alasdair Maddock',
#  'Alastor Gumboil',
#  'Albanian peasant',
#  'Alberic Grunnion',
#  'Albert Boot',
#  'Albert Jorkins',
#  'Albert Runcorn',
#  'Albert Tillyman',
#  'Alberta Toothill',
#  'Albus Dumbledore',
#  'Albus Potter',
#  'Alderton',
#  'Alecto Carrow',
#  'Alejandra Alonso',
#  'Alfred Cattermole',
#  'Alguff the Awful',
#  'Ali Bashir',
#  'Alice Longbottom',
#  'Alicia Spinnet',
#  'Aliko Okoye',
#  'Almerick Sawbridge',
#  'Alphard Black',
#  'Altheda',
#  'Amarillo Lestoat',
#  'Amata',
#  'Ambrosius Flume',
#  'Amelia Susan Bones',
#  'Amos Diggory',
#  'Amy Benson',
#  'Amycus Carrow',
#  'Andorran Minister for Magic',
#  'Andrew Kirke',
#  'Andromeda Tonks',
#  'Andros the Invincible',
#  'Angelina Johnson',
#  'Angelus Peel',
#  'Angus Buchanan',
#  'Angus Campbell',
#  'Angus Fleet',
#  'Angus McMangus',
#  'Annis Black',
#  'Anonymous',
#  'Anthony Goldstein',
#  'Antioch Peverell',
#  'Antonin Dolohov',
#  'Antonio',
#  'Apolline Delacour',
#  'Apollyon Pringle',
#  'Aragog',
#  'Araminta Meliflua',
#  'Archer Evermonde',
#  'Archibald Alderton',
#  'Archie',
#  'Archie Aymslowe',
#  'Arcturus Black (1884)',
#  'Arcturus Black (1901)',
#  'Arcus',
#  'Argus Filch',
#  'Argus Pyrites',
#  'Ariana Dumbledore',
#  'Aristotle Twelvetrees',
#  'Arkie Alderton',
#  'Arkie Philpott',
#  'Armand Malfoy',
#  'Armando Dippet',
#  'Armenian warlock',
#  'Arnie Peasegood',
#  'Arnold',
#  'Arnold Guzman',
#  'Arnulf Moe',
#  'Arsenia Gonzales',
#  'Arsenius Jigger',
#  'Artemisia Lufkin',
#  'Artemius Lawson',
#  'Arthur Weasley',
#  "Arthur's contact at the Floo Regulation Panel",
#  'Arturo Cephalopos',
#  'Asha',
#  'Astoria Greengrass',
#  'Audrey Weasley',
#  'Augusta "Gran" Longbottom',
#  'Augustus Pye',
#  'Augustus Rookwood',
#  'Augustus Worme',
#  'Aunt Marge Dursley',
#  'Auntie Muriel',
#  'Aurelius Dumbledore',
#  'Aurora Sinistra',
#  'Avery',
#  'B. Dunstan',
#  'BF',
#  'Babajide Akingbade',
#  'Babayaga',
#  'Babbitty Rabbitty',
#  'Bagman Sr.',
#  'Balfour Blane',
#  'Ballyfumble Stranger',
#  'Bandon Banshee',
#  'Bane',
#  'Barberus Bragge',
#  'Barebone Family',
#  'Barker',
#  'Barnabas Cuffe',
#  'Barnabas Deverill',
#  'Barnabas the Barmy',
#  'Barnabus Blenkinsop',
#  'Barnabus Finkley',
#  'Barnaby Snell',
#  'Barny the Fruitbat',
#  'Barry Ryan',
#  'Bartholomew Barebone',
#  'Barty Crouch Jr.',
#  'Barty Crouch Sr.',
#  'Baruffio',
#  'Basil',
#  'Basil Flack',
#  'Basil Horton',
#  'Bathilda Bagshot',
#  'Bathsheda Babbling',
#  'Beatrix Bloxam',
#  'Beaumont Marjoribanks',
#  'Beedle the Bard',
#  'Bellatrix Lestrange',
#  'Belvina Black',
#  'Benedita Dourado',
#  'Benjy Fenwick',
#  'Benjy Williams',
#  'Bernadette',
#  'Bernie Pillsworth',
#  'Bertha Jorkins',
#  "Bertha Jorkins' second cousin",
#  'Berthilde Roche',
#  'Bertie Bott',
#  'Bertie Higgs',
#  'Bertram Aubrey',
#  'Bertrand de Pensées-Profondes',
#  'Betty Braithwaite',
#  'Bill Weasley',
#  "Bill's penfriend from Brazil",
#  'Billy Stubbs',
#  'Binky',
#  'Blagdon Blay',
#  'Blaise Zabini',
#  "Blaise Zabini's mother",
#  'Blenheim Stalk',
#  'Bletchley',
#  'Blodwyn Bludd',
#  'Bludgeoning Boggart of Old London Town',
#  'Bob Hitchens',
#  'Bob Ogden',
#  'Bob, Bill, and Barnaby Ollerton',
#  'Bogomil Levski',
#  'Bogrod',
#  'Bole',
#  'Bonawentura Wójcik',
#  'Borgin',
#  'Boris Vulchanov',
#  'Boris the Bewildered',
#  'Bowman Wright',
#  'Bozo',
#  'Bradley',
#  'Bragging Young Wizard',
#  'Bran the Bloodthirsty',
#  'Brevis Birch',
#  'Brian Gadwilde',
#  'Bridget Wenlock',
#  "Bridget Wenlock's cousin",
#  'British envoy to the International Confederation of Wizards',
#  'Broderick Bode',
#  'Brodrig the Boss-Eyed',
#  'Brother Benedict',
#  'Brother Boniface',
#  'Bruno Bruunhart',
#  'Bruno Schmidt',
#  'Brutus Malfoy',
#  'Brutus Scrimgeour',
#  'Buckbeak',
#  'Buckley Cooper',
#  'Bungy the Budgie',
#  'Bunty',
#  'Burdock Muldoon',
#  'Cadmus Peverell',
#  'Cadwallader',
#  'Calchas',
#  'Callidora Black',
#  'Cantankerus Nott',
#  'Caractacus Burke',
#  'Caradoc Dearborn',
#  'Carlos Clodoaldo',
#  'Carlos Lopez',
#  'Carlotta Pinkstone',
#  'Carrow',
#  'Caspar Crouch',
#  'Cassandra Trelawney',
#  'Cassandra Vablatsky',
#  'Cassiopeia Black',
#  'Catriona McCormack',
#  'Catullus Spangle',
#  'Cecilia',
#  'Cecily',
#  'Cedrella Black Weasley',
#  'Cedric Diggory',
#  'Celestina Warbeck',
#  'Chadwick Boot',
#  'Chambers',
#  'Charis Black',
#  'Charity Burbage',
#  'Charity Wilkinson',
#  'Charlie Baverstock',
#  'Charlie Weasley',
#  'Charlus Potter',
#  'Chastity Barebone',
#  'Chauncey Oldridge',
#  'Cho Chang',
#  'Ciceron Harkiss',
#  'Circe',
#  'Clairvius Hyppolite',
#  'Clarisse Tremblay',
#  'Cliodna',
#  'Colin Creevey',
#  'Colonel Fubster',
#  'Connolly',
#  'Corban Yaxley',
#  'Cordelia Misericordia',
#  'Cormac McLaggen',
#  'Cormac O’Brien',
#  'Cormack McLeod',
#  'Cornelius Agrippa',
#  'Cornelius Fudge',
#  'Corvinus Gaunt',
#  'Corvus Lestrange Jr.',
#  'Corvus Lestrange Sr.',
#  'Count Vlad Drakul',
#  'Cousin Barny',
#  'Crabbe Sr.',
#  'Craig Bowker Jr.',
#  'Credence Barebone',
#  'Cresswell sons',
#  'Crispin Cronk',
#  'Crookshanks',
#  'Cuthbert Mockridge',
#  'Cyclops',
#  'Cygnus Black',
#  'Cygnus Black (1889)',
#  'Cyprian Youdle',
#  'D.J. Prod',
#  'Dagbert Pips',
#  'Daisy Dodderidge',
#  'Daisy Hookum',
#  'Daisy Pennifold',
#  'Damocles Belby',
#  'Damocles Rowle',
#  'Dangerous Dai Llewellyn',
#  'Daphne Greengrass',
#  'Darius Smackhammer',
#  'Dark Lord',
#  'Darren Floyd',
#  "Darren O'Hare",
#  'Davey Gudgeon',
#  'Dean Thomas',
#  "Dean Thomas' wizard father",
#  'Death',
#  'Death Eater with the baby head',
#  'Dedalus Diggle',
#  'Delfina Crimp',
#  'Delphi',
#  'Delphini Diggory',
#  'Demelza Robins',
#  'Demetrius J. Prod',
#  'Dempster Wiggleswade',
#  'Dennis',
#  'Dennis Bishop',
#  'Dennis Creevey',
#  'Dennis Moon',
#  'Derek',
#  'Derrick',
#  'Derwent Shimpling',
#  'Devlin Whitehorn',
#  'Dexter Fortescue',
#  'Diadema (Goshawk?)',
#  'Dilys Derwent',
#  'Dimitar Draganov',
#  'Dimitrov',
#  'Dirk Cresswell',
#  'Dishwasher at the Leaky Cauldron',
#  'Distractible Douglas',
#  'Dobby',
#  'Dodgy Dirk',
#  'Dolores Umbridge',
#  "Dolores Umbridge's brother",
#  'Dominique Weasley',
#  'Donaghan Tremlett',
#  'Dorcas Meadowes',
#  'Dorcas Wellbeloved',
#  'Dorcus Twelvetrees',
#  'Dorea Black Potter',
#  'Doris Crockford',
#  'Doris Purkiss',
#  'Dot',
#  'Dougal',
#  'Dougal McBride',
#  'Dougal McGregor',
#  'Dr. Ubbly',
#  'Draco Malfoy',
#  'Dragomir Despard',
#  'Dragomir Gorgovitch',
#  'Druella Rosier',
#  'Dudley Dursley',
#  'Dugald McPhail',
#  'Dunbar Oglethorpe',
#  'Dylan Marwood',
#  'Dymphna Furmage',
#  'Dzou Yen',
#  'Eargit the Ugly',
#  'Earl of Paunchley',
#  'Eddie Carmichael',
#  'Edgar Bones',
#  'Edgar Cloggs',
#  'Edgar Stroulger',
#  'Edmund Gaddlegate',
#  'Egbert the Egregious',
#  'Eglantine Puffett',
#  'Egmont Elvert Hobday',
#  'Eileen Prince Snape',
#  'Ekrizdis',
#  'Eldon Elsrickle',
#  'Eldred Worple',
#  'Eldritch Diggory',
#  'Eleanor Branstone',
#  'Elfric the Eager',
#  'Elfrida Clagg',
#  'Elfrida Cragg',
#  'Eliana',
#  'Elias Grimstone',
#  'Elias Story',
#  'Elizabeth McGilliguddy',
#  'Elizabeth Smudgling',
#  'Elladora Black (1850)',
#  'Elladora Black (aunt of Sirius)',
#  'Elladora Guffy',
#  'Elladora Ketteridge',
#  'Ellen Cracknell',
#  'Ellerby',
#  'Ellie Cattermole',
#  'Elliot Smethwyck',
#  'Elodie Dembélé',
#  'Eloise Midgen/Eloise Midgeon',
#  'Elphias Doge',
#  'Elphinstone Urquart',
#  'Elsie',
#  'Elsie Prod',
#  'Elveira Elkins',
#  'Emeric Switch',
#  'Emeric the Evil',
#  'Emily Rappaport',
#  'Emma Dobbs',
#  'Emmeline Vance',
#  'Enid Smeek',
#  'Eric Munch',
#  'Eric Whalley',
#  'Erica Stainwright',
#  'Ernie Macmillan',
#  'Ernie Prang',
#  'Errol',
#  'Ethelbald Mordaunt',
#  'Ethelred the Ever-Ready',
#  'Euan Abercrombie',
#  'Eugenia Jenkins',
#  'Eulalie Hicks',
#  'Eunice Murray',
#  'Euphemia Potter',
#  'Euphemia Rowle',
#  'Eupraxia Mole',
#  'Eurig Cadwallader',
#  'Evan Rosier',
#  'Evangeline Orpington',
#  'Everard',
#  'Fabian Prewett',
#  'Fabius Watkins',
#  'Falco Aesalon',
#  'Fang',
#  'Faris "Spout-hole" Spavin',
#  'Fawkes',
#  'Felix Summerbee',
#  'Fenrir Greyback',
#  'Ferdinand Jägendorf',
#  'Fergus',
#  'Fernando Diaz',
#  'Fifi LaFolle',
#  'Filibuster',
#  'Filius Flitwick',
#  'Finbar Quigley',
#  'Fingal the Fearless',
#  'Finn',
#  'Firenze',
#  'Flavius Belby',
#  'Fleamont Potter',
#  'Fleetwood',
#  'Fleur Delacour',
#  "Fleur's Veela grandmother",
#  'Florean Fortescue',
#  'Florence',
#  'Fluffy',
#  'Flurry',
#  'Food Trolley Lady aboard Hogwarts Express',
#  'Frank',
#  'Frank Bryce',
#  'Frank Longbottom',
#  'Franziska Faust',
#  'Fred Weasley',
#  'Fred Weasley (II)',
#  'Fridwulfa',
#  'Fulbert the Fearful',
#  'Gabriel Truman',
#  'Gabrielle Delacour',
#  'Galatea Merrythought',
#  'Galvin Gudgeon',
#  'Garrick Ollivander',
#  'Garvin Lünger',
#  'Gaspard Shingleton',
#  'Gawain Robards',
#  'Gellert Grindelwald',
#  'Gemma Farley',
#  'Geoffrey Hooper',
#  'George Weasley',
#  'Georgi Zdravko',
#  'Georgina Smyth',
#  'Georgios Xenakis',
#  'Geraint Ollivander',
#  'Gerbold Octavius Ollivander',
#  'Gerda Curd',
#  'Gertie Keddle',
#  'Gervaise Ollivander',
#  'Ghost of a knight with an arrow sticking out of his forehead',
#  'Ghost of a ragged man wearing chains',
#  'Ghosts of gloomy nuns',
#  'Gibbon',
#  'Gideon Crumb',
#  'Gideon Flatworthy',
#  'Gideon Prewett',
#  'Gifford Ollerton',
#  'Gilbert Wimple',
#  'Gilderoy Lockhart',
#  'Ginny Weasley',
#  'Gladys Boothby',
#  'Gladys Gudgeon',
#  'Glanmore Peakes',
#  'Glenda Chittock',
#  'Glinda Crook',
#  'Glover Hipworth',
#  'Glynnis Griffiths',
#  'Gnarlak',
#  'Godelot',
#  'Godric Gryffindor',
#  'Golgomath',
#  'Goliath',
#  'Golpalott',
#  'Gondoline Oliphant',
#  'Gondulphus Graves',
#  'Gonçalo Flores',
#  'Goodwin Kneen',
#  'Gordon',
#  'Gormlaith Gaunt',
#  'Gornuk',
#  'Goyle Sr.',
#  'Graham Pritchard',
#  'Granville Jorkins',
#  'Grawp',
#  'Great Auntie Enid',
#  'Great Uncle Algie',
#  'Greek chappie',
#  'Gregorovitch',
#  'Gregory Cotton',
#  'Gregory Goyle',
#  'Gregory the Smarmy',
#  'Greta Catchlove',
#  'Grimmson',
#  'Grimwold Jorkins',
#  'Gringott',
#  'Griphook',
#  'Griselda Harmonia Jorkins',
#  'Griselda Marchbanks',
#  'Grizel Hurtz',
#  'Grogan Stump',
#  'Grugwyn Rufford',
#  'Gulliver Pokeby',
#  'Gunhilda Kneen',
#  'Gunhilda of Gorsemoor',
#  'Gurg',
#  'Guthrie Lochrin',
#  'Gwendolyn Morgan',
#  'Gwenog',
#  'Gwenog Jones',
#  'Günther the Violent',
#  "Hagrid's father",
#  'Hambledon Quince',
#  'Hamish MacFarlan',
#  'Hankerton Humble',
#  'Hannah Abbott',
#  'Hannah Cockleford',
#  'Hans the Augurey',
#  'Hardwin, son of Linfred of Stinchcombe',
#  'Harfang Longbottom',
#  'Harfang Munter',
#  'Harold Dingle',
#  'Harold Minchum',
#  'Harold Skively',
#  'Harper',
#  'Harry Potter',
#  'Harvey Ridgebit',
#  'Hassan Mostafa',
#  'Havelock Sweeting',
#  'Heathcote Barbary',
#  'Hector Bolobolo',
#  'Hector Dagworth-Granger',
#  'Hector Fawley',
#  'Hector Lamont',
#  'Hedley Fleetwood',
#  'Hedwig',
#  'Heinrich Eberstadt',
#  'Helbert Spleen',
#  'Helena Ravenclaw',
#  'Helga Hufflepuff',
#  'Heliotrope Willis',
#  'Helixa Hyslop',
#  'Helmut Weiss',
#  'Hengist of Upper Barnton',
#  'Hengist of Woodcroft',
#  'Henry',
#  'Henry "Harry" Potter',
#  'Henry Shaw',
#  'Henry Shaw Jr.',
#  'Hepzibah Smith',
#  'Herbert Beery',
#  'Herbert Burke',
#  'Herbert Chorley',
#  'Hereward',
#  'Herman Junker',
#  'Herman Wintringham',
#  'Hermes',
#  'Hermione Granger',
#  'Herpo the Foul',
#  'Hesper Gamp',
#  'Hesper Starkey',
#  'Hesphaestus Gore',
#  'Hestia Jones',
#  'Hetty Bayliss',
#  'Hilliard Hobday',
#  'Hippocrates Smethwyck',
#  'Hodrod the Horny-Handed',
#  'Hogwarts governors',
#  'Hogwarts house-elves',
#  'Hokey',
#  'Honest Willy Wagstaff',
#  'Honoria',
#  'Honoria Nutcombe',
#  "Honoria's fiance",
#  'Hope Howell Lupin',
#  'Hoppy',
#  'Horace Slughorn',
#  'Hortensia Milliphutt',
#  'Howland Coopey',
#  'Hugo Granger-Weasley',
#  'Humphrey Belcher',
#  'Idris Oakby',
#  'Iefan Rice',
#  'Ignatia Wildsmith',
#  'Ignatius Prewett',
#  'Ignatius Tuft',
#  'Ignotus Peverell',
#  'Igor Karkaroff',
#  'Illyius',
#  'Ingolfr the Iambic',
#  'Inigo Imago',
#  'Injured girl comforted by Ginny',
#  'Iola Black',
#  'Iolanthe Peverell',
#  'Irene Kneedander',
#  'Irish Leprechauns',
#  'Irma Crabbe',
#  'Irma Dugard',
#  'Irma Pince',
#  'Irving Warble',
#  'Isadora Rose',
#  'Isobel McGonagall',
#  'Isobel Ross',
#  'Isolt Sayre',
#  'Ivan Popa',
#  'Ivanova',
#  'Ivor Dillonsby',
#  'J. Dorny',
#  'J. K. Rowling',
#  'Jack Sloper',
#  'Jackie Jernigan',
#  'Jacob Kowalski',
#  'Jacques Miskine',
#  'James Potter',
#  'James Sirius Potter',
#  'James Steward',
#  'Janus Thickey',
#  'Jarleth Hobart',
#  'Jazz singer',
#  'Jean-Baptiste Bloncourt',
#  'Jim McGuffin',
#  'Jimmy Peakes',
#  'Jocunda Sykes',
#  'Joey Jenkins',
#  'Johannes Jonker',
#  'John Dawlish',
#  'Joscelind Wadcock',
#  'Josef Wronski',
#  'Josefina Calderon',
#  'Joseph Snuka',
#  'Josephina Flint',
#  'Joshua Sankara',
#  'Josiah Jackson',
#  'Josiah Plunkett',
#  'José Barboza',
#  'João Coelho',
#  'Jugson',
#  'Justin Finch-Fletchley',
#  'Justus Pilliwickle',
#  'K. Bundy',
#  'Karkus',
#  'Karl Jenkins',
#  'Karl Wang',
#  'Karl and Kevin Broadmoor',
#  'Katie Bell',
#  'Kendra Dumbledore',
#  'Kenneth Towler',
#  'Kennilworthy Whisp',
#  'Kevin',
#  'Kevin Entwhistle',
#  'Kevin Hopwood',
#  'Kevin Whitby',
#  "Kevin's parents",
#  'Kimiko Kurosawa',
#  'King Arthur',
#  'King George III',
#  'King Henry VI',
#  'King William I',
#  'Kingsley Shacklebolt',
#  'Kirley Duke',
#  'Kquewanda Bailey',
#  'Krafft',
#  'Krall',
#  'Kreacher',
#  'Lachlan the Lanky',
#  'Ladislaw Zamojski',
#  'Lady Carmilla Sanguina',
#  'Lady Grieve',
#  'Lancelot',
#  'Landislaw Zamojski',
#  'Langdon Shaw',
#  'Lars Lundekvam',
#  'Laura Madley',
#  'Laurena Kama',
#  'Laurentia Fletwock',
#  'Lavender Brown',
#  'Laverne de Montmorency',
#  'Leanne',
#  'Lee Jordan',
#  'Lenelle Paraison',
#  'Lennox Campbell',
#  'Leonard Jewkes',
#  'Leonard Spencer-Moon',
#  'Leopoldina Smethwyk',
#  'Leta Lestrange',
#  'Leticia Somnolens',
#  'Levina Monkstanley',
#  'Levski',
#  'Libatius Borage',
#  'Lilith Molesby',
#  'Lily Luna Potter',
#  'Lily Moon',
#  'Lily Potter',
#  'Linfred of Stinchcombe',
#  'Lisa Turpin',
#  'Lisette de Lapin',
#  'Livius',
#  'Lorcan McLaird',
#  'Lorcan Scamander',
#  "Lorcan d'Eath",
#  'Lord North',
#  'Lord Palmerston',
#  'Lord Stoddard Withers',
#  'Lord Voldemort',
#  'Louis Weasley',
#  'Loxias',
#  'Luc Millefeuille',
#  'Lucas Bargeworthy',
#  'Lucas Picquery',
#  'Luciano Volpi',
#  'Lucius Malfoy',
#  'Lucius Malfoy (I)',
#  'Lucretia Black',
#  'Lucy Weasley',
#  'Ludo Bagman',
#  'Luna Lovegood',
#  'Lyall Lupin',
#  'Lycoris Black',
#  'Lysander Scamander',
#  'Lysandra Yaxley',
#  'MacFusty clan',
#  'Macduff',
#  'Mad-Eye Moody',
#  'Madam Edgecombe',
#  'Madam Eloise Mintumble',
#  'Madam Hooch',
#  'Madam Malkin',
#  'Madam Marsh',
#  'Madam Primpernelle',
#  'Madam Puddifoot',
#  'Madam Rosmerta',
#  'Madam Ya Zhou',
#  'Madam Z. Nettles',
#  'Madame Bonhabille',
#  'Mafalda',
#  'Mafalda Hopkirk',
#  'Magenta Comstock',
#  'Magnus "Dent Head" Macdonald',
#  'Magorian',
#  'Maisie Cattermole',
#  'Malcolm',
#  'Malcolm Baddock',
#  'Malcolm McGonagall',
#  'Mallory Twiddle',
#  'Malodora Grymm',
#  'Malécrit',
#  'Mandy Brocklehurst',
#  'Marcus Belby',
#  'Marcus Flint',
#  'Marietta Edgecombe',
#  'Marius',
#  'Marius Black',
#  'Mark Evans',
#  'Marlene McKinnon',
#  'Marlow',
#  "Martha Sayre Steward's husband",
#  'Martha Steward',
#  'Martha, mother of James Steward',
#  'Martin Miggs',
#  'Marvolo Gaunt',
#  'Mary Dorkins',
#  'Mary Elizabeth Cattermole',
#  'Mary Jauncey',
#  'Mary Lou Barebone',
#  'Mary MacDonald',
#  'Masaki Hongo',
#  'Matilda Dukelow',
#  'Mauler',
#  'Maximillian Crowdy',
#  'Maximus Brankovitch III',
#  'McClaggan',
#  'McClivert Clan',
#  'Meaghan McCormack',
#  'Megan Jones',
#  'Melania Macmillan',
#  'Melinda Bobbin',
#  'Melusine',
#  'Mentor Metaxas',
#  'Mercy Ojukwu',
#  'Mercy Wardwell',
#  'Merlin',
#  'Merope Gaunt',
#  'Merton Graves',
#  'Mervyn Fenwick',
#  'Merwyn the Malicious',
#  'Michael Corner',
#  'Miles Bletchley',
#  'Millicent Bagnold',
#  'Millicent Bulstrode',
#  'Milly',
#  'Minerva McGonagall',
#  'Minette Lestrange',
#  'Ministry wizard dealing with Archie',
#  'Ministry wizard dealing with toy broomstick incident',
#  'Ministry wizard in plus-fours',
#  'Ministry wizard in tweed suit and galoshes with large gold watch',
#  'Ministry wizards who carry the World Cup up to the Top Box',
#  'Ministry wizards who separate the Veela from the Leprechauns',
#  'Mirabella Plunkett',
#  'Miranda Goshawk (1921-)',
#  'Miranda Goshawk (fl. 1800)',
#  'Miriam Strout',
#  'Miss Pennyfeather',
#  'Miss S. Fawcett',
#  'Mnemone Radford',
#  'Moaning Myrtle',
#  'Modesty Barebone',
#  'Modesty Rabnott',
#  'Molly Weasley',
#  'Molly Weasley (II)',
#  'Momolou Wotorson',
#  'Monica Wilkins',
#  'Monsieur Delacour',
#  'Montague',
#  'Montague Knightly',
#  'Montgomery sisters',
#  'Mopsus (Divination professor)',
#  'Mopsus (Greek soothsayer)',
#  'Mopsy Fleabert',
#  'Morag Macdougal',
#  'Moran',
#  'Morfin Gaunt',
#  'Morgan',
#  'Morgana / Morgan le Fay',
#  'Morholt',
#  'Morrigan',
#  'Mortlake',
#  'Mosag',
#  'Mr Finch-Fletchley',
#  'Mr. Belby',
#  'Mr. Bingley',
#  'Mr. Boot',
#  'Mr. Borgin',
#  'Mr. Creevey',
#  'Mr. Evans',
#  'Mr. Finnigan',
#  'Mr. Granger',
#  'Mr. Jordan',
#  'Mr. Krum',
#  'Mr. Oblansk (or Obalonsk)',
#  'Mr. Paws',
#  'Mr. Payne',
#  'Mr. Prentice',
#  'Mr. Roberts',
#  'Mr. Summers',
#  'Mr. Tibbles',
#  'Mr. and Mrs. Bones',
#  'Mr. and Mrs. Mason',
#  'Mr. and Mrs. Montague',
#  'Mr. and Mrs. Patil',
#  'Mr. and Mrs. Riddle',
#  'Mr. and Mrs. Thomas',
#  'Mrs Fudge',
#  'Mrs. Abbott',
#  'Mrs. Boot',
#  'Mrs. Cole',
#  'Mrs. Cresswell',
#  'Mrs. Crouch',
#  'Mrs. Diggory',
#  'Mrs. Esposito',
#  'Mrs. Evans',
#  'Mrs. Figg',
#  'Mrs. Finch-Fletchley',
#  'Mrs. Finnigan',
#  'Mrs. Granger',
#  'Mrs. Krum',
#  'Mrs. Norris',
#  'Mrs. Polkiss',
#  'Mrs. Potter nee Fleamont',
#  'Mrs. Prod',
#  'Mrs. Roberts',
#  'Mrs. Skowers',
#  'Muggle Prime Minister',
#  'Muggle postal carrier on the Ottery St Catchpole route',
#  'Muggle postal carrier on the Privet Drive route',
#  'Muggle tramp',
#  'Mulciber',
#  'Mullet',
#  'Mundungus Fletcher',
#  'Mungo Bonham',
#  'Mungo MacDuff',
#  'Murcus',
#  'Musidora Barkwith',
#  'Mustafa Kama',
#  'Mylor Sylvanus',
#  'Myron Otherhaus',
#  'Myron Wagtail',
#  'Myrtle Warren',
#  'Nagel',
#  'Nagini',
#  'Nagnok',
#  'Narcissa Malfoy',
#  'Narinder Singh',
#  'Natalie McDonald',
#  'Nearly-Headless Nick',
#  'Nerida Vulchanova',
#  'Neville Longbottom',
#  "Neville's Grandad",
#  'Newt Scamander',
#  "Newt Scamander's mother",
#  'Ngapo Ponika',
#  'Nicholas Malfoy',
#  'Nicolas Flamel',
#  'Niko Nenad',
#  'Nikola Vassileva',
#  'Nobby Leach',
#  'Norbert/Norberta',
#  'Noriko Sato',
#  'Norvel Twonk',
#  'Nott',
#  'Nugent Potts',
#  'Nymphadora Tonks',
#  "O'Flaherty",
#  'O.W.L. Care of Magical Creatures Examiner',
#  'Oakden Hobday',
#  'Octavius Pepper',
#  'Oddvar Spillum',
#  'Odo the Hero',
#  'Ogden',
#  'Ogg',
#  'Olaf',
#  'Old Boggle of Canterbury',
#  'Old Mother Hubbard',
#  'Olive Hornby',
#  "Olive Hornby's brother",
#  'Oliver Rivers',
#  'Oliver Wood',
#  "Oliver Wood's parents",
#  'Olympe Maxime',
#  'Oona',
#  'Orabella Nuttley',
#  'Orford Umbridge',
#  'Orion Black',
#  'Orla Quirke',
#  'Orsino Thruston',
#  "Ortiz O'Flaherty",
#  'Oswald Beamish',
#  'Otmar Frick',
#  'Ottaline Gambol',
#  'Otto Bagman',
#  'Otto Obermeier',
#  'Over-Attentive Wizard',
#  'Owen Cauldwell',
#  'P.C. Anderson',
#  'Padma Patil',
#  'Pandora Lovegood',
#  'Panju Weasley',
#  'Pansy Parkinson',
#  'Paracelsus',
#  'Parvati Patil',
#  'Patricia Stimpson',
#  'Patrick',
#  'Peeves',
#  'Penelope Clearwater',
#  'Percival Dumbledore',
#  'Percival Graves',
#  'Percy Weasley',
#  'Perenelle Flamel',
#  'Perkins',
#  "Perkins (Binns' mistaken name for Harry)",
#  'Perpetua Fancourt',
#  'Perseus Parkinson',
#  'Peter Pettigrew',
#  "Peter Pettigrew's mother",
#  'Petrova Porskoff',
#  'Petunia Dursley',
#  'Philbert Deverill',
#  'Phineas Black',
#  'Phineas Fletcher',
#  'Phineas Nigellus Black',
#  'Phoebus Penrose',
#  'Phyllida Spore',
#  'Pickett',
#  'Pierre Bonaccord',
#  'Piers Polkiss',
#  'Pigwidgeon',
#  'Pinky',
#  'Pius Thicknesse',
#  'Poliakoff',
#  'Pollux Black',
#  'Polly Chapman',
#  'Pomona Sprout',
#  'Poppy',
#  'Poppy Pomfrey',
#  'Porteus Knatchbull',
#  'Portkey Tout',
#  'Portly ghost who was almost eating',
#  'Prendergast',
#  'Primrose Jorkins',
#  'Pringle',
#  'Priscilla Dupont',
#  'Professor Binns',
#  'Professor Mordicus Egg',
#  'Professor Saul Croaker',
#  'Professor Tofty',
#  'Professor Vector',
#  'Proudfoot',
#  'Prudence',
#  'Ptolemy',
#  ...]

# %%
characters_df = pd.DataFrame(list(characters.find()))
characters_df
# Out:
#                            _id                  Name  \
# 0     650a41e70846b16813a6827e      Euan Abercrombie
# 1     650a41e70846b16813a6827f     Achilles Tolliver
# 2     650a41e70846b16813a68280     Abraham Peasegood
# 3     650a41e70846b16813a68281     Adalbert Waffling
# 4     650a41e70846b16813a68282  Aberforth Dumbledore
# ...                        ...                   ...
# 1935  650a41e70846b16813a68a0d     Ryuichi Yamaguchi
# 1936  650a41e70846b16813a68a0e                Zograf
# 1937  650a41e70846b16813a68a0f                 Zonko
# 1938  650a41e70846b16813a68a10     Valentina Vázquez
# 1939  650a41e70846b16813a68a11         Zygmunt Budge
#
#                                                    Link  \
# 0     https://www.hp-lexicon.org/character/abercromb...
# 1     https://www.hp-lexicon.org/character/achilles-...
# 2     https://www.hp-lexicon.org/character/abraham-p...
# 3     https://www.hp-lexicon.org/character/adalbert-...
# 4     https://www.hp-lexicon.org/character/dumbledor...
# ...                                                 ...
# 1935  https://www.hp-lexicon.org/character/ryuichi-y...
# 1936       https://www.hp-lexicon.org/character/zograf/
# 1937        https://www.hp-lexicon.org/character/zonko/
# 1938  https://www.hp-lexicon.org/character/valentina...
# 1939  https://www.hp-lexicon.org/character/zygmunt-b...
#
#                                                   Descr  Gender Species/Race  \
# 0     Euan Abercrombie was a small boy with prominen...    Male       Wizard
# 1     Achilles Tolliver was an Auror whom Tina Golds...    Male       Wizard
# 2     Abraham Peasegood was an American wizard who i...    Male       Wizard
# 3     Adalbert Waffling was a famous magical theoret...    Male       Wizard
# 4     Aberforth Dumbledore was a tall, thin, grumpy-...    Male       Wizard
# ...                                                 ...     ...          ...
# 1935  Ryuichi Yamaguchi was a Chaser for Japan’s Nat...    Male       Wizard
# 1936  Zograf played Keeper for the Bulgarian Nationa...     NaN       Wizard
# 1937  Founder(?) of Zonko’s Joke Shop. Possibly a re...     NaN      Unknown
# 1938  Valentina Vázquez was President of the Argenti...  Female        Witch
# 1939  Zygmunt Budge is considered to be one of the m...    Male       Wizard
#
#                      School       Blood  \
# 0     Hogwarts - Gryffindor     Unknown
# 1                   Unknown     Unknown
# 2                   Unknown     Unknown
# 3                   Unknown     Unknown
# 4        Hogwarts - Student  Half-blood
# ...                     ...         ...
# 1935           Mahoutokouro     Unknown
# 1936                Unknown     Unknown
# 1937                Unknown     Unknown
# 1938                Unknown     Unknown
# 1939     Hogwarts - Student     Unknown
#
#                                          Profession
# 0                                           Unknown
# 1                                             Auror
# 2                                           Unknown
# 3                                            Author
# 4                                            Barman
# ...                                             ...
# 1935                      Quidditch player (Chaser)
# 1936                      Quidditch player (Keeper)
# 1937                                        Unknown
# 1938  President of the Argentinian Council of Magic
# 1939    Potions Master, Potioneer, Inventor, Author
#
# [1940 rows x 9 columns]

# %%
characters_df = characters_df.drop_duplicates(subset='Name', keep="first")
characters_df
# Out:
#                            _id                      Name  \
# 0     650a41e70846b16813a6827e          Euan Abercrombie
# 1     650a41e70846b16813a6827f         Achilles Tolliver
# 2     650a41e70846b16813a68280         Abraham Peasegood
# 3     650a41e70846b16813a68281         Adalbert Waffling
# 4     650a41e70846b16813a68282      Aberforth Dumbledore
# ...                        ...                       ...
# 1920  650a41e70846b16813a689fe                Yusuf Kama
# 1921  650a41e70846b16813a689ff                    Yvonne
# 1933  650a41e70846b16813a68a0b  several fifth-year girls
# 1936  650a41e70846b16813a68a0e                    Zograf
# 1937  650a41e70846b16813a68a0f                     Zonko
#
#                                                    Link  \
# 0     https://www.hp-lexicon.org/character/abercromb...
# 1     https://www.hp-lexicon.org/character/achilles-...
# 2     https://www.hp-lexicon.org/character/abraham-p...
# 3     https://www.hp-lexicon.org/character/adalbert-...
# 4     https://www.hp-lexicon.org/character/dumbledor...
# ...                                                 ...
# 1920   https://www.hp-lexicon.org/character/yusef-kama/
# 1921       https://www.hp-lexicon.org/character/yvonne/
# 1933  https://www.hp-lexicon.org/character/several-f...
# 1936       https://www.hp-lexicon.org/character/zograf/
# 1937        https://www.hp-lexicon.org/character/zonko/
#
#                                                   Descr  Gender Species/Race  \
# 0     Euan Abercrombie was a small boy with prominen...    Male       Wizard
# 1     Achilles Tolliver was an Auror whom Tina Golds...    Male       Wizard
# 2     Abraham Peasegood was an American wizard who i...    Male       Wizard
# 3     Adalbert Waffling was a famous magical theoret...    Male       Wizard
# 4     Aberforth Dumbledore was a tall, thin, grumpy-...    Male       Wizard
# ...                                                 ...     ...          ...
# 1920  Yusuf Kama was a French wizard of Senegalese a...    Male        Human
# 1921  Yvonne was a friend of Petunia Dursley who was...  Female       Muggle
# 1933                                                        NaN      Unknown
# 1936  Zograf played Keeper for the Bulgarian Nationa...     NaN       Wizard
# 1937  Founder(?) of Zonko’s Joke Shop. Possibly a re...     NaN      Unknown
#
#                      School       Blood                 Profession
# 0     Hogwarts - Gryffindor     Unknown                    Unknown
# 1                   Unknown     Unknown                      Auror
# 2                   Unknown     Unknown                    Unknown
# 3                   Unknown     Unknown                     Author
# 4        Hogwarts - Student  Half-blood                     Barman
# ...                     ...         ...                        ...
# 1920                Unknown  Pure blood                    Unknown
# 1921                Unknown      Muggle                    Unknown
# 1933                Unknown     Unknown                    Unknown
# 1936                Unknown     Unknown  Quidditch player (Keeper)
# 1937                Unknown     Unknown                    Unknown
#
# [1350 rows x 9 columns]

# %%
characters_df = characters_df.drop_duplicates(subset='Descr', keep="first")
characters_df
# Out:
#                            _id                    Name  \
# 0     650a41e70846b16813a6827e        Euan Abercrombie
# 1     650a41e70846b16813a6827f       Achilles Tolliver
# 2     650a41e70846b16813a68280       Abraham Peasegood
# 3     650a41e70846b16813a68281       Adalbert Waffling
# 4     650a41e70846b16813a68282    Aberforth Dumbledore
# ...                        ...                     ...
# 1919  650a41e70846b16813a689fd  Young Red-Haired Witch
# 1920  650a41e70846b16813a689fe              Yusuf Kama
# 1921  650a41e70846b16813a689ff                  Yvonne
# 1936  650a41e70846b16813a68a0e                  Zograf
# 1937  650a41e70846b16813a68a0f                   Zonko
#
#                                                    Link  \
# 0     https://www.hp-lexicon.org/character/abercromb...
# 1     https://www.hp-lexicon.org/character/achilles-...
# 2     https://www.hp-lexicon.org/character/abraham-p...
# 3     https://www.hp-lexicon.org/character/adalbert-...
# 4     https://www.hp-lexicon.org/character/dumbledor...
# ...                                                 ...
# 1919  https://www.hp-lexicon.org/character/young-red...
# 1920   https://www.hp-lexicon.org/character/yusef-kama/
# 1921       https://www.hp-lexicon.org/character/yvonne/
# 1936       https://www.hp-lexicon.org/character/zograf/
# 1937        https://www.hp-lexicon.org/character/zonko/
#
#                                                   Descr  Gender Species/Race  \
# 0     Euan Abercrombie was a small boy with prominen...    Male       Wizard
# 1     Achilles Tolliver was an Auror whom Tina Golds...    Male       Wizard
# 2     Abraham Peasegood was an American wizard who i...    Male       Wizard
# 3     Adalbert Waffling was a famous magical theoret...    Male       Wizard
# 4     Aberforth Dumbledore was a tall, thin, grumpy-...    Male       Wizard
# ...                                                 ...     ...          ...
# 1919  In early September of 1927, a young red-haired...  Female        Human
# 1920  Yusuf Kama was a French wizard of Senegalese a...    Male        Human
# 1921  Yvonne was a friend of Petunia Dursley who was...  Female       Muggle
# 1936  Zograf played Keeper for the Bulgarian Nationa...     NaN       Wizard
# 1937  Founder(?) of Zonko’s Joke Shop. Possibly a re...     NaN      Unknown
#
#                      School       Blood                 Profession
# 0     Hogwarts - Gryffindor     Unknown                    Unknown
# 1                   Unknown     Unknown                      Auror
# 2                   Unknown     Unknown                    Unknown
# 3                   Unknown     Unknown                     Author
# 4        Hogwarts - Student  Half-blood                     Barman
# ...                     ...         ...                        ...
# 1919                Unknown     Unknown                    Unknown
# 1920                Unknown  Pure blood                    Unknown
# 1921                Unknown      Muggle                    Unknown
# 1936                Unknown     Unknown  Quidditch player (Keeper)
# 1937                Unknown     Unknown                    Unknown
#
# [1179 rows x 9 columns]

# %%
characters.deleteMany({ })
mongo['harrypotter']['characters'].insertMany({characters_df.to_dict('records')})
db = mongo['harrypotter']
characters = db['characters']
gryffindor_count = characters.count_documents({'School':'Hogwarts - Gryffindor'})
gryffindor_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mongo['harrypotter']['characters'].deleteMany({ })
#       2 mongo['harrypotter']['characters'].insertMany({characters_df.to_dict('records')})
#       3 db = mongo['harrypotter']
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pymongo/collection.py:3485, in Collection.__call__(self, *args, **kwargs)
#    3479 if "." not in self.__name:
#    3480     raise TypeError("'Collection' object is not callable. If you "
#    3481                     "meant to call the '%s' method on a 'Database' "
#    3482                     "object it is failing because no such method "
#    3483                     "exists." %
#    3484                     self.__name)
# -> 3485 raise TypeError("'Collection' object is not callable. If you meant to "
#    3486                 "call the '%s' method on a 'Collection' object it is "
#    3487                 "failing because no such method exists." %
#    3488                 self.__name.split(".")[-1])
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'deleteMany' method on a 'Collection' object it is failing because no such method exists.
